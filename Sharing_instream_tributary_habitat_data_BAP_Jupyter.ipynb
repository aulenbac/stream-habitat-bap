# %%
library(tidyverse)
library(openxlsx)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# To accelerate research and decision making data needs to be findable, accessible, interoperable, and reusable (FAIR). Multiple federal, state and tribal agencies collect in-stream and riparian habitat metrics to answer management questions specific to their program goals. This analysis package integrates data from two different aquatic monitoring programs; BLM AIM and EPA Rivers and Streams (Table1) . We would like to integrate two US Forest Service in-stream aquatic habitat monitoring programs, but their data is not publicity accessible.

# %%
#Packages to create well formated tables in RStuido 
library(knitr)
library(DT)
library(gridExtra)
library(kableExtra)
# Out:
# Attaching package: 'gridExtra'
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
# Attaching package: 'kableExtra'
#
# The following object is masked from 'package:dplyr':
#
#     group_rows

# %% [markdown]
# # Background

# %% [markdown]
# To accelerate research and decision making data needs to be findable, accessible, interoperable, and reusable (FAIR). Multiple federal, state and tribal agencies collect in-stream and riparian habitat metrics to answer management questions specific to their program goals. This analysis package integrates data from two different aquatic monitoring programs; BLM AIM and EPA Rivers and Streams (Table1) . We would like to integrate two US Forest Service in-stream aquatic habitat monitoring programs, but their data is not publicity accessible.

# %%
program_info<-read.xlsx("Data/Metadata.xlsx", 1) %>% as_tibble()

#kable(program_info) %>%
 #   kable_styling(bootstrap_options = c("striped", "hover", fixed_header=TRUE ))

program_info
# Out:
#    Entity
# 1  Program
# 2  Abbreviation
# 3  Primary Objective
# 4  Year Started
# 5  Site Length
# 6  Spatial Design
# 7  Target Population
# 8  Master Sample Details
# 9  Additional Spatial Design Details
# 10 Base Temporal Scale
# 11 Temporal Design
# 12 Sample Period
# 13 Quality Control
# 14 Protocol
# 15 Comments
# 16 Additional References
#    Bureau.of.Land.Management
# 1  Assessment, Inventory, and Monitoring
# 2  AIM Aquatic
# 3  A consistent, quantitative approach for determining the attainment of BLM land health standards for perennial wadeable streams and rivers, among other applications.  Monitoring\nobjectives are established by project managers and will determine the number of\nreaches to be sampled and whether a randomized, targeted, or mixed site\nselection approach is appropriate.
# 4  2011
# 5  20 x bankfull width, a minimum of 150m
# 6  Stratified GRTS, Targeted sites
# 7  Surveys conducted in wadeable streams within BLM Bruneau Field Offices
# 8  Resolution ?
# 9  NA
# 10 Annual
# 11 NA
# 12 NA
# 13 Field personnel training, standard protocol
# 14 https://aim.landscapetoolbox.org/wp-content/uploads/2018/10/TR_1735-02.pdf
# 15 NA
# 16 https://aim.landscapetoolbox.org/wp-content/uploads/2018/01/AIM-strategy011818.pdf
#    US.Forest.Service.and.Bureau.of.Land.Management
# 1  Aquatic and Riparian Effective Monitoring Program
# 2  AREMP
# 3  Status and Trend
# 4  2002
# 5  20x bankfull width categories, range 150m-500m
# 6  Non-stratified GRTS
# 7  Surveys conducted in wadeable stream within the Northwest Forest Plan Area in Watersheds with at least 25% of the 1:100K streams layers within federal ownership.
# 8  NA
# 9  NA
# 10 Annual
# 11 NA
# 12 NA
# 13 Field personnel training, standard protocol, 9 watersheds are surveyed
# 14 http://www.reo\n.gov/monitoring\n/reports/watershed/2010.Field Protocol.Final.pdf\n
# 15 NA
# 16 NA
#    Environmental.Protection.Agency
# 1  National Rivers and Streams Assessment
# 2  NRSA
# 3  A collaborative survey that provides information on the ecological condition of the nation’s rivers and streams and the key stressors that affect them, both on a national and an ecoregional scale. \nThe goals of the NRSA are to determine the extent to which rivers and streams support a healthy biological condition and the extent of major stressors that affect them. The survey supports a longer-term goal: to determine whether our rivers and streams are getting cleaner and how we might best invest in protecting and restoring them.
# 4  2008
# 5  20x channel-widths, a minimum of 150m
# 6  GRTS
# 7  The target population consists of all streams and rivers within the 48 contiguous states that have flowing water during the study index period, including major rivers and small streams. Sites must have > 50% of the reach length with standing water, and sites with water in less than 50% of the reach length must be dropped. All sites must be sampled during base flow conditions. The target population excludes:\n• Tidal rivers and streams up to head of salt (defined as < 0.5 ppt for this study).\n• Run-of-the-river ponds and reservoirs with greater than seven day residence time.\nThe study index period extends from
# 8  NA
# 9  The survey design consists of two separate designs to address the dual objectives of: \n(1)estimating current status and (2) estimating change in status for all flowing waters:\n• Resample design applied to NRSA 2008/09 and NRSA 2013/14 sites.\n• New site design for NRSA 2018/19.\nThe survey design is explicitly stratified by state for both designs. The unequal probability categories are specific to the survey design used for the NRSA 2008/09, NRSA 2013/14, and NRSA 2018/19. In all cases the categories are specific combinations of Strahler order categories and nine National Aquatic Resource Survey (NARS) aggregated ecoregions. In addition, a minimum of 20 sites (Resample and New) was guaranteed in each state and a maximum of 75 sites was the limit for an individual state. There are 983 unique sites in the Resample Design and 825 unique sites in the New Site Design. Approximately 10% of the total NRSA sites are scheduled for repeated sampling (revisit sites) in the same year of the two year NRSA field cycle. The sample frame was derived from the medium resolution National Hydrography Dataset (NHD), in particular NHDPlus V2. Additional details on the NRSA survey design are found in the National Rivers and Streams Assessment Survey Design: 2018/19 documents.
# 10 2008-2009, 2013-2014, 2018-2019
# 11 NA
# 12 o Beginning of June through end of September for most regions.\no Sites in the select ecoregions or States can be sampled starting in the end of\nApril with approval from the EPA Project Coordinator.
# 13 Field personnel training, standard protocol
# 14 https://www.epa.gov/sites/production/files/2019-05/documents/nrsa_1819_fom_wadeable_version_1.2_0.pdf
# 15 Survey conducted in wadable and bootable streams across the United States. Sampling locations are selected using a modern survey design approach called a probability-based sample design. In such a design, every element in the population has a known probability of being selected for sampling. This important feature ensures that the results of the survey reflect the full range in character and variation among flowing waters across the U.S. Site selection rules included weighting to provide balance in the number of river and stream sites from each of the size classes.
# 16 NA
#    US.Forest.Service
# 1  PACFISH/INFISH Biological Opinion Effectiveness Monitoring
# 2  PIBO EM
# 3  The primary objective is to determine whether\npriority biological and physical attributes, processes, and functions of riparian\nand aquatic systems are being degraded, maintained, or restored in the\nPIBO monitoring area.
# 4  1998
# 5   20x bankfull channel\nwidths, range from 160m-480m
# 6  GRTS, Targeted sites
# 7  Target popultion cosists of 6th fieldhydrologic unit code (HUC) watersheds within perennial streams and greater than 50 percent Federal ownership above the sample reach.\n
# 8  NA
# 9  NA
# 10 Annual (5-year rotating panel)
# 11 We will then resample the same watersheds over subsequent 5-year periods. This design is represented as a rotating panel that is serially augmented and alternates over a given period (Urquhart and others 1998). Initially, we will randomly select the subsample of reference and managed watersheds within the group. Our goal will be to select an even number of “reference” and “managed” watersheds for sampling. Because the number of “reference” watersheds is generally low, we will sample as many as possible within the group, up to half of the total number of watersheds.
# 12 NA
# 13 Field personnel training, standard protocol
# 14 https://www.fs.usda.gov/Internet/FSE_DOCUMENTS/fseprd494543.pdf
# 15 Survey conducted in wadeable streams within the interior ColumbiaRiver basin on lands managed by U.S.orest Service (FS) Regions 1, 4, and 6 and the Idaho and Oregon/Washington State Offices of the Bureau of Land Management (BLM). (AND UPPER MISSOURI? )
# 16 https://www.fs.usda.gov/detail/r4/landmanagement/resourcemanagement/?cid=stelprd3845865

# %%
#Read in the data dictionary 
metadata <-read.xlsx("Data/Metadata.xlsx", 3) %>% as_tibble()

#kable(metadata %>%
#  group_by(Category)%>%
#  count(Category, sort=TRUE))

metadata
# Out:
#     Order Category
# 1   1     Identification
# 2   1     Identification
# 3   1     Identification
# 4   1     Identification
# 5   1     Identification
# 6   1     Identification
# 7   1     Identification
# 8   1     Identification
# 9   1     Identification
# 10  1     Identification
# 11  1     Identification
# 12  1     Identification
# 13  1     Identification
# 14  1     Identification
# 15  1     Identification
# 16  1     Identification
# 17  1     Identification
# 18  1     Identification
# 19  1     Identification
# 20  1     Identification
# 21  1     Identification
# 22  1     Identification
# 23  2     Location
# 24  2     Location
# 25  2     Location
# 26  2     Location
# 27  2     Location
# 28  2     Location
# 29  2     Location
# 30  2     Location
# ... ...   ...
# 275 14    Macroinvertebrates
# 276 14    Macroinvertebrates
# 277 14    Macroinvertebrates
# 278 14    Macroinvertebrates
# 279 14    Macroinvertebrates
# 280 14    Macroinvertebrates
# 281 14    Macroinvertebrates
# 282 14    Macroinvertebrates
# 283 16    Overhead Cover
# 284 16    Overhead Cover
# 285 16    Overhead Cover
# 286 16    Overhead Cover
# 287 17    Human disturbance
# 288 17    Human disturbance
# 289 17    Human disturbance
# 290 17    Human disturbance
# 291 17    Human disturbance
# 292 17    Human disturbance
# 293 17    Human disturbance
# 294 17    Human disturbance
# 295 17    Human disturbance
# 296 17    Human disturbance
# 297 17    Human disturbance
# 298 17    Human disturbance
# 299 17    Human disturbance
# 300 17    Human disturbance
# 301 19    Management
# 302 19    Management
# 303 20    Other/Covariates
# 304 20    Other/Covariates
#     Name                                                      ShortName
# 1   Reach ID number                                           ReachID
# 2   Site ID number                                            SiteID
# 3   Sample Year                                               Year
# 4   Sample Date                                               Date
# 5   PIBO Use of Site                                          NA
# 6   PIBO Sample Type                                          NA
# 7   Panel year                                                NA
# 8   EPA Site Class                                            NA
# 9   EPA X Site Status                                         NA
# 10  Use visit in NRSA population estimates                    NA
# 11  EPA Great river site                                      NA
# 12  Count of Visits per Year                                  NA
# 13  Site Name                                                 NA
# 14  PIBO Group                                                NA
# 15  PIBO Order                                                NA
# 16  Protocol                                                  NA
# 17  BLM Merge of Site Code                                    NA
# 18  Visit Number                                              NA
# 19  BLM Project                                               NA
# 20  BLM Stratum                                               NA
# 21  Targeted or Random                                        NA
# 22  Field Status Notes                                        NA
# 23  Latitude                                                  BRLat
# 24  Longitude                                                 BRLong
# 25  Stream Name                                               StreamName
# 26  FS Region or BLM State Office                             Region
# 27  FS Forest or BLM District                                 Forest
# 28  Forest Service District or BLM Field Office/Resource Area District
# 29  State                                                     State
# 30  Nominal latitude in decimal degrees                       NA
# ... ...                                                       ...
# 275  Number of Mollusca taxa                                  NA
# 276 Mollusca abundance                                        NA
# 277  Number of Insect taxa                                    NA
# 278 Insect abundance                                          NA
# 279  Number of non-insect taxa                                NA
# 280 Non-insect abundance                                      NA
# 281 Number of Intolerant taxa                                 Intol
# 282 RIVPAC's score of observed / expected taxa                NA
# 283 Percent Overhead Cover                                    NA
# 284 Average percent overhead cover provided by stream banks   NA
# 285 Mean Canopy Density at Bank                               NA
# 286 Mean Canopy Density at Mid- Channel                       NA
# 287 EPA Human Disturbacne Indix- Argicultural Influence       NA
# 288 EPA Human Distrubance Index                               NA
# 289 EPA Human Distrubance Index - Non-Argicultura             NA
# 290 Distance to Buildings                                     NA
# 291 Count of Near Channel Disturbance                         NA
# 292 Distance to Trash/Landfill                                NA
# 293 Distance to Logging                                       NA
# 294 Distance to Mining                                        NA
# 295 Distance to Lawn/Park                                     NA
# 296 Distance to Pipes (infl/Effl)                             NA
# 297 Distance to Pasture or Hayfield                           NA
# 298 Distance to Pavement                                      NA
# 299 Distance to Road/Railroad                                 NA
# 300 Count of Near Channel Disturbance                         NA
# 301 Percent FS / BLM                                          NA
# 302 Management Category                                       NA
# 303 Date the Data Was Change                                  NA
# 304 Reason and Field Changed                                  NA
#     DataType                    AREMPColumn       AREMPLongName
# 1   NA                          site_survey_id    NA
# 2   NA                          site_id           NA
# 3   Int                         survey_year       NA
# 4   What data type is a date?   survey_date       NA
# 5   NA                          NA                NA
# 6   NA                          NA                NA
# 7   NA                          NA                NA
# 8   NA                          NA                NA
# 9   NA                          NA                NA
# 10  NA                          NA                NA
# 11  NA                          NA                NA
# 12  NA                          NA                NA
# 13  NA                          NA                NA
# 14  NA                          NA                NA
# 15  NA                          NA                NA
# 16  NA                          survey_type       NA
# 17  NA                          NA                NA
# 18  NA                          NA                NA
# 19  NA                          NA                NA
# 20  NA                          NA                NA
# 21  NA                          NA                NA
# 22  NA                          NA                NA
# 23  Long                        lattitude         NA
# 24  Long                        longitude         NA
# 25  String                      NA                NA
# 26  String                      NA                NA
# 27  String                      NA                NA
# 28  String                      NA                NA
# 29  String                      state             NA
# 30  NA                          NA                NA
# ... ...                         ...               ...
# 275 NA                          Mollusca_num_tx   # of Mollusca taxa
# 276 NA                          Mollusca_abd      Mollusca abundance
# 277 NA                          insect_num_tx     # of Insect taxa
# 278 NA                          insect_abd        Insect abundance
# 279 NA                          noninsect_num_tx  # of non-insect taxa
# 280 NA                          noninsect_abd     Non-insect abundance
# 281 Int                         intolerant_num_tx NA
# 282 NA                          NA                NA
# 283 NA                          NA                NA
# 284 NA                          NA                NA
# 285 NA                          NA                NA
# 286 NA                          NA                NA
# 287 NA                          NA                NA
# 288 NA                          NA                NA
# 289 NA                          NA                NA
# 290 NA                          NA                NA
# 291 NA                          NA                NA
# 292 NA                          NA                NA
# 293 NA                          NA                NA
# 294 NA                          NA                NA
# 295 NA                          NA                NA
# 296 NA                          NA                NA
# 297 NA                          NA                NA
# 298 NA                          NA                NA
# 299 NA                          NA                NA
# 300 NA                          NA                NA
# 301 NA                          NA                NA
# 302 NA                          NA                NA
# 303 NA                          NA                NA
# 304 NA                          NA                NA
#     AREMPDescription AREMPUnites AREMPCollectionMethod ... EPACollectionMethod
# 1   NA               NA          NA                    ... NA
# 2   NA               NA          NA                    ... NA
# 3   NA               NA          NA                    ... NA
# 4   NA               NA          NA                    ... NA
# 5   NA               NA          NA                    ... NA
# 6   NA               NA          NA                    ... NA
# 7   NA               NA          NA                    ... NA
# 8   NA               NA          NA                    ... NA
# 9   NA               NA          NA                    ... NA
# 10  NA               NA          NA                    ... NA
# 11  NA               NA          NA                    ... NA
# 12  NA               NA          NA                    ... NA
# 13  NA               NA          NA                    ... NA
# 14  NA               NA          NA                    ... NA
# 15  NA               NA          NA                    ... NA
# 16  NA               NA          NA                    ... NA
# 17  NA               NA          NA                    ... NA
# 18  NA               NA          NA                    ... NA
# 19  NA               NA          NA                    ... NA
# 20  NA               NA          NA                    ... NA
# 21  NA               NA          NA                    ... NA
# 22  NA               NA          NA                    ... NA
# 23  NA               NA          NA                    ... NA
# 24  NA               NA          NA                    ... NA
# 25  NA               NA          NA                    ... NA
# 26  NA               NA          NA                    ... NA
# 27  NA               NA          NA                    ... NA
# 28  NA               NA          NA                    ... NA
# 29  NA               NA          NA                    ... NA
# 30  NA               NA          NA                    ... NA
# ... ...              ...         ...                       ...
# 275 NA               NA          NA                    ... NA
# 276 NA               NA          NA                    ... NA
# 277 NA               NA          NA                    ... NA
# 278 NA               NA          NA                    ... NA
# 279 NA               NA          NA                    ... NA
# 280 NA               NA          NA                    ... NA
# 281 NA               NA          NA                    ... NA
# 282 NA               NA          NA                    ... NA
# 283 NA               NA          NA                    ... NA
# 284 NA               NA          NA                    ... NA
# 285 NA               NA          NA                    ... NA
# 286 NA               NA          NA                    ... NA
# 287 NA               NA          NA                    ... NA
# 288 NA               NA          NA                    ... NA
# 289 NA               NA          NA                    ... NA
# 290 NA               NA          NA                    ... NA
# 291 NA               NA          NA                    ... NA
# 292 NA               NA          NA                    ... NA
# 293 NA               NA          NA                    ... NA
# 294 NA               NA          NA                    ... NA
# 295 NA               NA          NA                    ... NA
# 296 NA               NA          NA                    ... NA
# 297 NA               NA          NA                    ... NA
# 298 NA               NA          NA                    ... NA
# 299 NA               NA          NA                    ... NA
# 300 NA               NA          NA                    ... NA
# 301 NA               NA          NA                    ... NA
# 302 NA               NA          NA                    ... NA
# 303 NA               NA          NA                    ... NA
# 304 NA               NA          NA                    ... NA
#     EPAAnalysisMethod Long.Name-.PIBO
# 1   NA                Reach ID number
# 2   NA                Site ID number
# 3   NA                Sampling Year
# 4   NA                NA
# 5   NA                Intended use of site
# 6   NA                PIBO sample type
# 7   NA                Panel year
# 8   NA                NA
# 9   NA                NA
# 10  NA                NA
# 11  NA                NA
# 12  NA                NA
# 13  NA                Site Name
# 14  NA                Group
# 15  NA                Order
# 16  NA                NA
# 17  NA                NA
# 18  NA                NA
# 19  NA                NA
# 20  NA                NA
# 21  NA                NA
# 22  NA                NA
# 23  NA                Latitude
# 24  NA                Longitude
# 25  NA                Stream Name
# 26  NA                FS Region or BLM State Office
# 27  NA                FS Forest or BLM District
# 28  NA                Forest Service District or BLM Field Office/Resource Area
# 29  NA                State
# 30  NA                NA
# ... ...               ...
# 275 NA                NA
# 276 NA                NA
# 277 NA                NA
# 278 NA                NA
# 279 NA                NA
# 280 NA                NA
# 281 NA                Number of Intolerant taxa
# 282 NA                RIVPAC's score of observed / expected taxa
# 283 NA                NA
# 284 NA                NA
# 285 NA                NA
# 286 NA                NA
# 287 NA                NA
# 288 NA                NA
# 289 NA                NA
# 290 NA                NA
# 291 NA                NA
# 292 NA                NA
# 293 NA                NA
# 294 NA                NA
# 295 NA                NA
# 296 NA                NA
# 297 NA                NA
# 298 NA                NA
# 299 NA                NA
# 300 NA                NA
# 301 NA                Percent FS / BLM
# 302 NA                Management Category
# 303 NA                NA
# 304 NA                NA
#     PIBOColumn
# 1   RchID
# 2   SiteID
# 3   Yr
# 4   NA
# 5   Project
# 6   Type
# 7   PanelYr
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  SiteName
# 14  Group
# 15  Order
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  Lat
# 24  Long
# 25  Stream
# 26  Region
# 27  Forest
# 28  District
# 29  State
# 30  NA
# ... ...
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 Intol
# 282 RIVPACS
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
# 290 NA
# 291 NA
# 292 NA
# 293 NA
# 294 NA
# 295 NA
# 296 NA
# 297 NA
# 298 NA
# 299 NA
# 300 NA
# 301 FedPct
# 302 Mgmt
# 303 NA
# 304 NA
#     PIBO.Description
# 1   Unique number that identifies one sample of a particular site.
# 2   Number that identifies a unique sampling location. A site is a stream segment with a fixed starting and ending location for sampling.
# 3   NA
# 4   NA
# 5   CRB = Site included in PIBO EM rotating 5-year sample design within the Upper Columbia River Basin study area.\nMRB = Site included in PIBO EM rotating 5-year sample design within the Upper Missouri River Basin study area.\nCNTRCT = Sampling funded by local Forest Service or BLM field units.\nFS = Sites sampled by Forest Service employees using PIBO EM sampling protocol.\n
# 6   In general, type refers to the 1) site selection criteria, and 2) the sampling methods used to collect data.\nI = In-stream habitat, stream temperature, aquatic macroinvertebrate, and riparian vegetation are collected. Integrator sites are the most downstream stream segment within a randomly selected ICBEMP 6th field hydrologic unit less than 3% gradient (ideally), no tributaries, and no beaver activity when sites are established.\nS = Sentinels, Type I sites that are sampled annually.\nP = Prairie sites. These, typically dry, streambeds are evaluated under a separate protocol and are not comparable to other site types.\nK = Designated Monitoring Area (DMA). Riparian vegetation data and a subset of in-stream habitat data are collected. Sampling locations are identified by local field unit personnel as locations utilized for livestock grazing implementation monitoring (IM).\n
# 7   Relevant to CRB and MRB sites which are sampled on a 5-year rotation. Panel year 1 sites are sampled 2001, 2006, 2011, etc. Panel year 2 sites are sampled 2002, 2007, 2012, etc.
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  Concatenation of Group-Order-Type
# 14  A group is a 3-digit numeric code used to identify a spatial cluster of ~20 6th field sub-watersheds. Groups 1-177 are in the CRB, 200-299 are in the MRB. Group numbers >500 are used to label CNTRCT and FS sites.
# 15  An order is a randomly assigned, 2-digit, numeric code that uniquely identifies 6th field sub-watersheds within a group.
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  Coordinates for mapping. Coordinates were derived by: 1) plotting NAD 1927 (WGS 1984 for 2012 - p) UTM coordinates recorded by field crews in GIS; 2) moving each point to the appropriate location on the 1:24000 National Hydrography Dataset (NHD; http://nhd.usgs.gov/) stream line if necessary; 3) converting units to Latitude/Longitude coordinates in Albers Equal Area. NOTE: these coordinates are not suitable for locating sites on the ground.
# 24  Coordinates for mapping. Coordinates were derived by: 1) plotting NAD 1927 (WGS 1984 for 2012 - p) UTM coordinates recorded by field crews in GIS; 2) moving each point to the appropriate location on the 1:24000 National Hydrography Dataset (NHD; http://nhd.usgs.gov/) stream line if necessary; 3) converting units to Latitude/Longitude coordinates in Albers Equal Area. NOTE: these coordinates are not suitable for locating sites on the ground.
# 25  NA
# 26  Forest Service Region, BLM state office, or overseeing federal agency where site occurs.
# 27  Forest Service Forest or BLM District where site occurs.
# 28  FS District, ID BLM Field Office, or OR-WA BLM Resource Area where site occurs.
# ...
# 295 NA
# 296 NA
# 297 NA
# 298 NA
# 299 NA
# 300 NA
# 301 Percent of the catchment upstream of a site owned by Forest Service / BLM.
# 302 Managed or Reference. Reference sites have minimal management: catchment road densities less than 0.5 km/km2, riparian road densities less than 0.25 km/km2, no grazing within 30 years, and no known in-channel mining upstream of the integrator site.
# 303 NA
# 304 NA
#     PIBOUnits                         PIBOCollectionMethod PIBOAnalysisMethod
# 1   integer                           NA                   NA
# 2   integer                           NA                   NA
# 3   integer                           NA                   NA
# 4   NA                                NA                   NA
# 5   categorical: CRB, MRB, CNTRCT, FS NA                   NA
# 6   categorical: I, IS, IK, IKS, K, P NA                   NA
# 7   integer                           NA                   NA
# 8   NA                                NA                   NA
# 9   NA                                NA                   NA
# 10  NA                                NA                   NA
# 11  NA                                NA                   NA
# 12  NA                                NA                   NA
# 13  NA                                NA                   NA
# 14  integer                           NA                   NA
# 15  integer                           NA                   NA
# 16  NA                                NA                   NA
# 17  NA                                NA                   NA
# 18  NA                                NA                   NA
# 19  NA                                NA                   NA
# 20  NA                                NA                   NA
# 21  NA                                NA                   NA
# 22  NA                                NA                   NA
# 23  Decimal degree                    NA                   NA
# 24  Decimal degree                    NA                   NA
# 25  NA                                NA                   NA
# 26  NA                                NA                   NA
# 27  NA                                NA                   NA
# 28  NA                                NA                   NA
# 29  NA                                NA                   NA
# 30  NA                                NA                   NA
# ... ...                               ...                  ...
# 275 NA                                NA                   NA
# 276 NA                                NA                   NA
# 277 NA                                NA                   NA
# 278 NA                                NA                   NA
# 279 NA                                NA                   NA
# 280 NA                                NA                   NA
# 281 NA                                NA                   NA
# 282 NA                                NA                   NA
# 283 NA                                NA                   NA
# 284 NA                                NA                   NA
# 285 NA                                NA                   NA
# 286 NA                                NA                   NA
# 287 NA                                NA                   NA
# 288 NA                                NA                   NA
# 289 NA                                NA                   NA
# 290 NA                                NA                   NA
# 291 NA                                NA                   NA
# 292 NA                                NA                   NA
# 293 NA                                NA                   NA
# 294 NA                                NA                   NA
# 295 NA                                NA                   NA
# 296 NA                                NA                   NA
# 297 NA                                NA                   NA
# 298 NA                                NA                   NA
# 299 NA                                NA                   NA
# 300 NA                                NA                   NA
# 301 percent                           NA                   NA
# 302 categorical: managed or reference NA                   NA
# 303 NA                                NA                   NA
# 304 NA                                NA                   NA
#     CountPrograms X38
# 1   4             NA
# 2   4             NA
# 3   3             NA
# 4   3             NA
# 5   1             NA
# 6   1             NA
# 7   1             NA
# 8   1             NA
# 9   1             NA
# 10  1             NA
# 11  1             NA
# 12  1             NA
# 13  1             NA
# 14  1             NA
# 15  1             NA
# 16  2             NA
# 17  1             NA
# 18  1             NA
# 19  1             NA
# 20  1             NA
# 21  1             NA
# 22  1             NA
# 23  4             NA
# 24  4             NA
# 25  2             NA
# 26  2             NA
# 27  2             NA
# 28  2             NA
# 29  2             NA
# 30  1             NA
# ... ...           ...
# 275 1             NA
# 276 1             NA
# 277 1             NA
# 278 1             NA
# 279 1             NA
# 280 1             NA
# 281 2             Intol
# 282 1             RIVPACS
# 283 1             NA
# 284 1             NA
# 285 1             NA
# 286 1             NA
# 287 1             NA
# 288 1             NA
# 289 1             NA
# 290 1             NA
# 291 1             NA
# 292 1             NA
# 293 1             NA
# 294 1             NA
# 295 1             NA
# 296 1             NA
# 297 1             NA
# 298 1             NA
# 299 1             NA
# 300 1             NA
# 301 1             NA
# 302 1             NA
# 303 1             NA
# 304 1             NA

# %%
install.packages("leaflet")
library(leaflet)
library(rgdal)
library(htmlwidgets)
# Out:
# package 'leaflet' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\2\Rtmpw5tDuH\downloaded_packages
# Error: package or namespace load failed for 'leaflet' in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]):
#  namespace 'htmltools' 0.3.6 is already loaded, but >= 0.4.0 is required
# Traceback:
#
# 1. library(leaflet)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %%
data<- read.csv("Data/All_Data.csv") 
  
  pal <- colorFactor(rainbow(3), data$Program)
  data <-data %>% drop_na(BRLong) %>% drop_na(BRLat)
  m <-data %>% 
      leaflet() %>%
      addTiles() %>%
      addCircles(lng=~BRLong, lat= ~BRLat, color=~pal(Program), 
                            popup= ~paste0("<b>",  Program, "</b>", 
                             "<br>", "<b>", "ReachID ", "</b>",  ReachID, "</br>",
                             "<br>", "<b>", "SiteID ", "</b>",SiteID,  "</br>",
                             "<br>", "<b>", "Year ", "</b>", Year,    "</br>",
                             "<br>", "<b>", "Date ", "</b>", Date,    "</br>")) %>%
                              addLegend("topright", pal=pal, values= ~Program, opacity =1)
m   
#map_filename = paste0(getwd(),"Map/map.html")

#saveWidget(widget=m, file=paste0(getwd(),"/Map/map.html"), selfcontained=T)
# Out:
# Error in colorFactor(rainbow(3), data$Program): could not find function "colorFactor"
# Traceback:

# %%
# Pull Method data from MR.org based on the metric we are intrested in. 
#I DON'T KNOW HOW TO make the HTML look correct 
source("Code/data_organize/metric_documentation.R")
PctPoolMetadata <- metric_information("PctPool")
print(PctPoolMetadata)

#kable(PctPoolMetadata)%>%
 #   kable_styling(bootstrap_options = c("striped", "hover", fixed_header=TRUE ))
# Out:
# Warning message:
# "No data found on worksheet."
# Error in if (!is.na(id)) {: argument is of length zero
# Traceback:
#
# 1. metric_information("PctPool")

# %%
data %>%
  group_by(Program) %>%
  summarize(mean(PctPool, na.rm=T))
# Out:
#   Program mean(PctPool, na.rm = T)
# 1 BLM     17.58701
# 2 EPA     25.26724
# 3 PIBO    38.02454

# %%
ggplot(data, aes(x=Grad, y=PctPool))+ geom_point()+facet_wrap(~Program)
# Out:
# Warning message:
# "Removed 931 rows containing missing values (geom_point)."
# plot without title

# %%
data %>%
  group_by(Program) %>%
  summarize(mean(PctPool, na.rm=T))
# Out:
#   Program mean(PctPool, na.rm = T)
# 1 BLM     17.58701
# 2 EPA     25.26724
# 3 PIBO    38.02454

# %%
ggplot(data, aes(PctPool))+geom_histogram()+facet_wrap(~Program)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# "Removed 840 rows containing non-finite values (stat_bin)."
# plot without title
