# %% [markdown]
# # Background
#
# To accelerate research and decision making data needs to be findable, accessible, interoperable, and reusable (FAIR). Multiple federal, state and tribal agencies collect in-stream and riparian habitat metrics to answer management questions specific to their program goals.
#
# A working group compiled of partners from EPA National Aquatic Resources Survey (NARS), BLM Assessment, Inventory, and Monitoring (AIM), and the USFS Pacfish/Infish Biological Opinion Effectiveness Monitoring (PIBO-EM) and Aquatic and Riparian Effectiveness Monitoring Program (AREMP) have compiled program informaiton and undertaken

# %%
install.packages("xlsx")
library(xlsx)

install.packages("openxlsx")
library(openxlsx)

install.packages("tidyverse")
library(tidyverse)

#Packages to create well formated tables in RStuido 
install.packages("knitr")
library(knitr)
install.packages("kableExtra")
library(kableExtra)

# packages for downloading and formaing shapefiles 
install.packages("downloader")
library(downloader)

install.packages("rgdal")
library(rgdal)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~up yes 
#install.packages("leaflet")
#library(leaflet)

#install.packages("sf")
#library(sf)

#install.packages("formattable")

#install.packages("DT")
#library(DT)

#install.packages("RCurl")
#library(RCurl)


#library(rstudioapi)
#library(ggplot2)
#library(formattable)
#library(htmltools)



#library(gridExtra)
# Out:
# package 'xlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# package 'openxlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'openxlsx' was built under R version 3.6.2"
# Attaching package: 'openxlsx'
#
# The following objects are masked from 'package:xlsx':
#
#     createWorkbook, loadWorkbook, read.xlsx, saveWorkbook, write.xlsx
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'tidyverse' was built under R version 3.6.2"-- Attaching packages --------------------------------------- tidyverse 1.3.0 --
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'ggplot2' was built under R version 3.6.2"Warning message:
# "package 'tibble' was built under R version 3.6.2"Warning message:
# "package 'tidyr' was built under R version 3.6.2"Warning message:
# "package 'purrr' was built under R version 3.6.2"Warning message:
# "package 'dplyr' was built under R version 3.6.2"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# package 'knitr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'knitr' was built under R version 3.6.2"
# package 'kableExtra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'kableExtra' was built under R version 3.6.2"
# Attaching package: 'kableExtra'
#
# The following object is masked from 'package:dplyr':
#
#     group_rows
# package 'downloader' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'downloader' was built under R version 3.6.2"
# package 'rgdal' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rscully\AppData\Local\Temp\1\Rtmp218KGj\downloaded_packages
# Warning message:
# "package 'rgdal' was built under R version 3.6.2"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.6.2"rgdal: version: 1.4-8, (SVN revision 845)
#  Geospatial Data Abstraction Library extensions to R successfully loaded
#  Loaded GDAL runtime: GDAL 2.2.3, released 2017/11/20
#  Path to GDAL shared files: C:/Users/rscully/AppData/Local/Continuum/anaconda3/envs/Instream Habitat Data/Lib/R/library/rgdal/gdal
#  GDAL binary built with GEOS: TRUE
#  Loaded PROJ.4 runtime: Rel. 4.9.3, 15 August 2016, [PJ_VERSION: 493]
#  Path to PROJ.4 shared files: C:/Users/rscully/AppData/Local/Continuum/anaconda3/envs/Instream Habitat Data/Lib/R/library/rgdal/proj
#  Linking to sp version: 1.3-2

# %% [markdown]
# # Program Information
# This analysis package integrates data from two different aquatic monitoring programs; BLM AIM and EPA Rivers and Streams (Table1).
#
# <h2>Monitoring Program Information</h2>
# Each monitoring program was established to answer different management questions appalying different spatial and temporal designs and protocols.

# %%
wd= getwd()
metadata_name= paste(wd, "/Data/Metadata.xlsx", sep="")
program_info<-as_tibble(read.xlsx(metadata_name, 1))
program_info
# Out:
#    Entity
# 1  Program
# 2  Abbreviation
# 3  Primary Objective
# 4  Year Started
# 5  Site Length
# 6  Spatial Design
# 7  Target Population
# 8  Master Sample Details
# 9  Additional Spatial Design Details
# 10 Base Temporal Scale
# 11 Temporal Design
# 12 Sample Period
# 13 Quality Control
# 14 Protocol
# 15 Comments
# 16 Additional References
#    Bureau.of.Land.Management
# 1  Assessment, Inventory, and Monitoring
# 2  AIM Aquatic
# 3  A consistent, quantitative approach for determining the attainment of BLM land health standards for perennial wadeable streams and rivers, among other applications.  Monitoring\nobjectives are established by project managers and will determine the number of\nreaches to be sampled and whether a randomized, targeted, or mixed site\nselection approach is appropriate.
# 4  2011
# 5  20 x bankfull width, a minimum of 150m
# 6  Stratified GRTS, Targeted sites
# 7  Surveys conducted in wadeable streams within BLM Bruneau Field Offices
# 8  Resolution ?
# 9  NA
# 10 Annual
# 11 NA
# 12 NA
# 13 Field personnel training, standard protocol
# 14 https://aim.landscapetoolbox.org/wp-content/uploads/2018/10/TR_1735-02.pdf
# 15 NA
# 16 https://aim.landscapetoolbox.org/wp-content/uploads/2018/01/AIM-strategy011818.pdf
#    US.Forest.Service.and.Bureau.of.Land.Management
# 1  Aquatic and Riparian Effective Monitoring Program
# 2  AREMP
# 3  Status and Trend
# 4  2002
# 5  20x bankfull width categories, range 150m-500m
# 6  Non-stratified GRTS
# 7  Surveys conducted in wadeable stream within the Northwest Forest Plan Area in Watersheds with at least 25% of the 1:100K streams layers within federal ownership.
# 8  NA
# 9  NA
# 10 Annual
# 11 NA
# 12 NA
# 13 Field personnel training, standard protocol, 9 watersheds are surveyed
# 14 http://www.reo\n.gov/monitoring\n/reports/watershed/2010.Field Protocol.Final.pdf\n
# 15 NA
# 16 NA
#    Environmental.Protection.Agency
# 1  National Rivers and Streams Assessment
# 2  NRSA
# 3  A collaborative survey that provides information on the ecological condition of the nation’s rivers and streams and the key stressors that affect them, both on a national and an ecoregional scale. \nThe goals of the NRSA are to determine the extent to which rivers and streams support a healthy biological condition and the extent of major stressors that affect them. The survey supports a longer-term goal: to determine whether our rivers and streams are getting cleaner and how we might best invest in protecting and restoring them.
# 4  2008
# 5  20x channel-widths, a minimum of 150m
# 6  GRTS
# 7  The target population consists of all streams and rivers within the 48 contiguous states that have flowing water during the study index period, including major rivers and small streams. Sites must have > 50% of the reach length with standing water, and sites with water in less than 50% of the reach length must be dropped. All sites must be sampled during base flow conditions. The target population excludes:\n• Tidal rivers and streams up to head of salt (defined as < 0.5 ppt for this study).\n• Run-of-the-river ponds and reservoirs with greater than seven day residence time.\nThe study index period extends from
# 8  NA
# 9  The survey design consists of two separate designs to address the dual objectives of: \n(1)estimating current status and (2) estimating change in status for all flowing waters:\n• Resample design applied to NRSA 2008/09 and NRSA 2013/14 sites.\n• New site design for NRSA 2018/19.\nThe survey design is explicitly stratified by state for both designs. The unequal probability categories are specific to the survey design used for the NRSA 2008/09, NRSA 2013/14, and NRSA 2018/19. In all cases the categories are specific combinations of Strahler order categories and nine National Aquatic Resource Survey (NARS) aggregated ecoregions. In addition, a minimum of 20 sites (Resample and New) was guaranteed in each state and a maximum of 75 sites was the limit for an individual state. There are 983 unique sites in the Resample Design and 825 unique sites in the New Site Design. Approximately 10% of the total NRSA sites are scheduled for repeated sampling (revisit sites) in the same year of the two year NRSA field cycle. The sample frame was derived from the medium resolution National Hydrography Dataset (NHD), in particular NHDPlus V2. Additional details on the NRSA survey design are found in the National Rivers and Streams Assessment Survey Design: 2018/19 documents.
# 10 2008-2009, 2013-2014, 2018-2019
# 11 NA
# 12 o Beginning of June through end of September for most regions.\no Sites in the select ecoregions or States can be sampled starting in the end of\nApril with approval from the EPA Project Coordinator.
# 13 Field personnel training, standard protocol
# 14 https://www.epa.gov/sites/production/files/2019-05/documents/nrsa_1819_fom_wadeable_version_1.2_0.pdf
# 15 Survey conducted in wadable and bootable streams across the United States. Sampling locations are selected using a modern survey design approach called a probability-based sample design. In such a design, every element in the population has a known probability of being selected for sampling. This important feature ensures that the results of the survey reflect the full range in character and variation among flowing waters across the U.S. Site selection rules included weighting to provide balance in the number of river and stream sites from each of the size classes.
# 16 NA
#    US.Forest.Service
# 1  PACFISH/INFISH Biological Opinion Effectiveness Monitoring
# 2  PIBO EM
# 3  The primary objective is to determine whether\npriority biological and physical attributes, processes, and functions of riparian\nand aquatic systems are being degraded, maintained, or restored in the\nPIBO monitoring area.
# 4  1998
# 5   20x bankfull channel\nwidths, range from 160m-480m
# 6  GRTS, Targeted sites
# 7  Target popultion cosists of 6th fieldhydrologic unit code (HUC) watersheds within perennial streams and greater than 50 percent Federal ownership above the sample reach.\n
# 8  NA
# 9  NA
# 10 Annual (5-year rotating panel)
# 11 We will then resample the same watersheds over subsequent 5-year periods. This design is represented as a rotating panel that is serially augmented and alternates over a given period (Urquhart and others 1998). Initially, we will randomly select the subsample of reference and managed watersheds within the group. Our goal will be to select an even number of “reference” and “managed” watersheds for sampling. Because the number of “reference” watersheds is generally low, we will sample as many as possible within the group, up to half of the total number of watersheds.
# 12 NA
# 13 Field personnel training, standard protocol
# 14 https://www.fs.usda.gov/Internet/FSE_DOCUMENTS/fseprd494543.pdf
# 15 Survey conducted in wadeable streams within the interior ColumbiaRiver basin on lands managed by U.S.orest Service (FS) Regions 1, 4, and 6 and the Idaho and Oregon/Washington State Offices of the Bureau of Land Management (BLM). (AND UPPER MISSOURI? )
# 16 https://www.fs.usda.gov/detail/r4/landmanagement/resourcemanagement/?cid=stelprd3845865
# [1] 16  5

# %% [markdown]
# <h3> Program Metrics </h3>
# We have compiled metadata from the four programs descibing the metrics calculated by each program. Each program calculates a exatnstive list of methods, summarized by catagories between the four programs we found:  classified each metirc into a catagory, table 2 shows the count of metrics by catagory.

# %% [markdown]
# A subset of metrics is calculated by more then three of the programs:

# %%
#Read in the data dictionary 
metadata <-read.xlsx(metadata_name, 3)

metadata_summary<- metadata %>%
  group_by(Category)%>%
  count(Category, sort=TRUE)

metadata_summary
# Out:
#    Category                n
# 1  Macroinvertebrates      72
# 2  Substrate               31
# 3  Channel Characteristics 27
# 4  Channel dimensions      25
# 5  Wood                    24
# 6  Identification          22
# 7  Human disturbance       14
# 8  Location                14
# 9  Bed stability           13
# 10 Streambanks             13
# 11 Fish cover              12
# 12 Water chemistry         11
# 13 Environment              9
# 14 Pools                    8
# 15 Overhead Cover           4
# 16 Management               2
# 17 Other/Covariates         2
# 18 Index Value              1
# [1] 18  2

# %%
file <- paste(wd,"/Code/Data_Organize/create_list_of_metrics.R",sep='')
source(file)
metrics_list<-metrics()
count<-str(dim(metrics_list))
print(count[1], 'are caculated by three of more of the monitoring programs')
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"
#  int [1:2] 22 8
# Warning message in print.default(count[1], "are caculated by three of more of the monitoring programs"):
# "NAs introduced by coercion"
# Error in print.default(count[1], "are caculated by three of more of the monitoring programs"): invalid 'digits' argument
# Traceback:
#
# 1. print(count[1], "are caculated by three of more of the monitoring programs")
# 2. print.default(count[1], "are caculated by three of more of the monitoring programs")

# %%
metrics_list
metrics_list %>% dim()
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"
# # A tibble: 22 x 8
#    Category Name  ShortName AREMPColumn BLMColumn EPAColumn PIBOColumn
#    <chr>    <chr> <chr>     <chr>       <chr>     <chr>     <chr>
#  1 Identif~ "Rea~ ReachID   site_surve~ UID       UID       RchID
#  2 Identif~ "Sit~ SiteID    site_id     MS_CD     SITE_ID   SiteID
#  3 Identif~ "Sam~ Year      survey_year <NA>      YEAR      Yr
#  4 Identif~ "Sam~ Date      survey_date DT        DATE_COL  <NA>
#  5 Location "Lat~ BRLat     lattitude   BTMLAT    LAT_DD83  Lat
#  6 Location "Lon~ BRLong    longitude   BTMLONG   LON_DD83  Long
#  7 Channel~ "Ave~ BFWidth   ave_bfwidth BNKFLL_WT XBKF_W    Bf
#  8 Channel~ "Gra~ Grad      gradient    SLPE      XSLOPE    Grad
#  9 Channel~ "Len~ RchLen    reach_leng~ TOT_RCH_~ REACHLEN  RchLen
# 10 Channel~ "Ban~ BF_WDRat~ ave_widthD~ <NA>      BFWD_RAT  WDTrans
# # ... with 12 more rows, and 1 more variable: Count.of.Program <dbl>
#   Category       Name            ShortName AREMPColumn    BLMColumn EPAColumn
# 1 Identification Reach ID number ReachID   site_survey_id UID       UID
# 2 Identification Site ID number  SiteID    site_id        MS_CD     SITE_ID
# 3 Identification Sample Year     Year      survey_year    NA        YEAR
# 4 Identification Sample Date     Date      survey_date    DT        DATE_COL
# 5 Location       Latitude        BRLat     lattitude      BTMLAT    LAT_DD83
# 6 Location       Longitude       BRLong    longitude      BTMLONG   LON_DD83
#   PIBOColumn Count.of.Program
# 1 RchID      4
# 2 SiteID     4
# 3 Yr         3
# 4 NA         3
# 5 Lat        4
# 6 Long       4
# [1] 22  8

# %% [markdown]
# # Data Sources
# ## Metric Data
#
# Two of the four habitat programs store metric level data online, BLM and EPA. Below is the code to pull data from the published sources and combind the information into one file.
#
# <h3> BLM AIM Data </h3>
# The BLM AIM published their data on the <a href="https://landscape.blm.gov/geoportal/catalog/main/home.page">Landscape Approach Data Portal</a>. Pull down the most recient data file and open the geodatabase. If the BLM changes the location of the data the code will need to be updated

# %%
#URL Location of the AIM GeoDataBase of data collection locations, if the BLM updates the .zip file this link will need to be updated 
fileURL<-"https://gis.blm.gov/AIMDownload/LayerPackages/BLM_AIM_AquADat.zip"

#Download the file to the Data file
download_BLM = paste(wd,'/Data/BLM.zip', sep='')
download(fileURL, download_BLM)

##Unzip the file into the Data File 
extract_file <-paste(wd,"/Data", sep="")
unzip(download_BLM, exdir=extract_file)

#Define the file path to the geodata base, if the BLM changes their file structure this will need to be updated 
fgdb=path.expand('Data/BLM_AIM_AquADat/v104/AquADat_data.gdb')

BLM_geo<- readOGR(dsn=fgdb)
BLM_projection <- BLM_geo@proj4string
BLM <- BLM_geo@data

#write the datafile to the datafile in the repository
BLM_file= paste(wd, '/Data/BLM.csv', sep="")
write.csv(BLM, BLM_file)
head(BLM)

# %% [markdown]
# <h3>EMA Rivers and Streams Data </h3>
# EPA collects data across the Unites States and publised their metric level data here!!!!!!!

# %%
source_file= paste(wd,'/Code/Data_Organize/Pull EPA Data.R', sep='')
source(source_file)
#Fuction to pull EPA data from the user assigned webpage, clean, save and organize the wadable stream data
#This does now work when connect to the vpn (I HAVE NO IDEA WHY?)
EPA <-Pull_EPA("https://www.epa.gov/sites/production/files/2015-09/phabmed.csv") 
head(EPA)

# %% [markdown]
# # Create one Data File
# To complete anaysis we create one data frame from the two program.

# %%
#file = paste(wd,"/Code/Data_Organize/create_list_of_metrics.R",sep='')
file=path.expand("Code/data_organize/creating one dataframe_for loop.R")
#source("Code/data_organize/creating one dataframe_for loop.R")
source(file)
data<-one_data_frame()

# %% [markdown]
# ## NEED TO ADD INFORMATION ABOUT CALCULATING COVARIATES, Sky calculated x used in the following example

# %% [markdown]
# # Exlore Data

# %%
The BLM AIM Program and the EPA

# %%
file<- path.expand("Code/Visualization/Shiney_map_reactive_tabs.R")
#file<- paste(wd,"/Visualization/Shiney_map_reactive_tabs.R",sep='')
source(file)
explore_data()

# %%
file
